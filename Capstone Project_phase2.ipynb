# %%
import sqlite3
from sqlite3 import Error

import pandas as pd
import numpy as np

# %% [markdown]
# Creating DB Connection

# %%
def create_connection(db_file):
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        return conn
    except Error as e:
        print(e)

conn = create_connection(r"C:\Users\Asus\CapstoneDB\imdb_data.db")
conn.close()

# %%
conn = create_connection(r"C:\Users\Asus\CapstoneDB\imdb_data.db")
cur = conn.cursor()

# %% [markdown]
# Creating 1st table

# %%
tble1 = """CREATE TABLE directors (
    Sno INTEGER,
    MovieName TEXT,
    Duration INTEGER,
    Year INTEGER,
    Ratings REAL,
    Metascore INTEGER,
    Director1 TEXT,
    Director2 TEXT,
    Director3 TEXT,
    Director4 TEXT,
    Director5 TEXT,
    Director6 TEXT,
    Director7 TEXT,
    Director8 TEXT,
    Director9 TEXT,
    Director10 TEXT
);
"""
cur.execute(tble1)

# %%
df1 = pd.read_csv("imdb_data1.csv", header=0)

# %%
df1.head()
# Out:
#    S.no                                         Movie Name  Duration  Year  \
# 0     1                                    The Dark Knight       152  2008
# 1     2      The Lord of the Rings: The Return of the King       201  2003
# 2     3                Spider-Man: Across the Spider-Verse       140  2023
# 3     4                                          Inception       148  2010
# 4     5  The Lord of the Rings: The Fellowship of the Ring       178  2001
#
#    Ratings  Metascore           Director1          Director2  \
# 0      9.0       84.0   Christopher Nolan     Christian Bale
# 1      9.0       94.0       Peter Jackson        Elijah Wood
# 2      8.8       86.0  Joaquim Dos Santos        Kemp Powers
# 3      8.8       74.0   Christopher Nolan  Leonardo DiCaprio
# 4      8.8       92.0       Peter Jackson        Elijah Wood
#
#               Director3      Director4         Director5          Director6  \
# ...

# %%
df1.to_sql('directors', conn, if_exists='replace', index=False)
# Out:
# 1775

# %% [markdown]
# Creating 2nd table

# %%
tble2 = """CREATE TABLE stars (
    MovieName TEXT,
    Votes INTEGER,
    GrossCollection REAL,
    Popularity REAL,
    Certification TEXT,
    Star1 TEXT,
    Star2 TEXT,
    Star3 TEXT,
    Star4 TEXT,
    Star5 TEXT,
    Star6 TEXT,
    Star7 TEXT,
    Star8 TEXT,
    Star9 TEXT,
    Genre1 TEXT,
    Genre2 TEXT,
    Genre3 TEXT
);
"""
cur.execute(tble2)

# %%
df2 = pd.read_csv("imdb_data2.csv", header=0)

# %%
df2.head()
# Out:
#                                           Movie Name    Votes  \
# 0                                    The Dark Knight  2759160
# 1      The Lord of the Rings: The Return of the King  1906339
# 2                Spider-Man: Across the Spider-Verse   208178
# 3                                          Inception  2449482
# 4  The Lord of the Rings: The Fellowship of the Ring  1934546
#
#   Gross collection  Popularity Certification              Star1  \
# 0      534,858,444         9.0            UA     Christian Bale
# 1      377,845,905         9.0             U        Elijah Wood
# 2           208178         8.8             U        Kemp Powers
# 3      292,576,195         8.8            UA  Leonardo DiCaprio
# 4      315,544,750         8.8             U        Elijah Wood
#
#                   Star2          Star3             Star4              Star5  \
# 0          Heath Ledger  Aaron Eckhart     Michael Caine                NaN
# ...

# %%
df2.to_sql('stars', conn, if_exists='replace', index=False)
# Out:
# 1775

# %% [markdown]
# 1. Display all the details of movies created by directors Christopher and Matt Reeves

# %%
qry = "SELECT * FROM directors WHERE Director1 IN ('Christopher Nolan', 'Matt Reeves') \
         OR Director2 IN ('Christopher Nolan', 'Matt Reeves') \
         OR Director3 IN ('Christopher Nolan', 'Matt Reeves') \
         OR Director4 IN ('Christopher Nolan', 'Matt Reeves') \
         OR Director5 IN ('Christopher Nolan', 'Matt Reeves') \
         OR Director6 IN ('Christopher Nolan', 'Matt Reeves') \
         OR Director7 IN ('Christopher Nolan', 'Matt Reeves') \
         OR Director8 IN ('Christopher Nolan', 'Matt Reeves') \
         OR Director9 IN ('Christopher Nolan', 'Matt Reeves');"
df_qry = pd.read_sql_query(qry, conn)
df_qry
# Out:
#    S.no                      Movie Name  Duration  Year  Ratings  Metascore  \
# 0     1                 The Dark Knight       152  2008      9.0       84.0
# 1     4                       Inception       148  2010      8.8       74.0
# 2    17           The Dark Knight Rises       164  2012      8.4       78.0
# 3    37                   Batman Begins       140  2005      8.2       70.0
# 4   130                         Dunkirk       106  2017      7.8       94.0
# 5   132                      The Batman       176  2022      7.8       72.0
# 6   226  Dawn of the Planet of the Apes       130  2014      7.6       79.0
# 7   312  War for the Planet of the Apes       140  2017      7.4       82.0
# 8   325                           Tenet       150  2020      7.3       69.0
# 9   521                     Cloverfield        85  2008      7.0       64.0
#
#            Director1              Director2             Director3  \
# ...

# %% [markdown]
# 2. Display all the details of movies with a duration of 140 minutes to 190 minutes

# %%
qry = "SELECT * FROM directors WHERE Duration >= 140 and Duration <= 190;"
df_qry = pd.read_sql_query(qry, conn)
df_qry
# Out:
#      S.no                                         Movie Name  Duration  Year  \
# 0       1                                    The Dark Knight       152  2008
# 1       3                Spider-Man: Across the Spider-Verse       140  2023
# 2       4                                          Inception       148  2010
# 3       5  The Lord of the Rings: The Fellowship of the Ring       178  2001
# 4       6              The Lord of the Rings: The Two Towers       179  2002
# ..    ...                                                ...       ...   ...
# 203  1762                                              Liger       140  2022
# 204  1763                                             Gunday       152  2014
# 205  1766                                        Heropanti 2       145  2022
# 206  1767                                             Laxmii       141  2020
# 207  1772                                             Race 3       160  2018
#
# ...

# %% [markdown]
# 3. Display all the details of movies with ratings above 7 in ascending order

# %%
qry = "SELECT * FROM directors WHERE Ratings > 7 ORDER BY Ratings ASC;"
df_qry = pd.read_sql_query(qry, conn)
df_qry
# Out:
#      S.no                                         Movie Name  Duration  Year  \
# 0     435                                Mission: Impossible       110  1996
# 1     436                                          The Mummy       124  1999
# 2     437                                       Man of Steel       143  2013
# 3     438                                      American Made       114  2017
# 4     439                                           WarGames       114  1983
# ..    ...                                                ...       ...   ...
# 488     4                                          Inception       148  2010
# 489     5  The Lord of the Rings: The Fellowship of the Ring       178  2001
# 490     6              The Lord of the Rings: The Two Towers       179  2002
# 491     1                                    The Dark Knight       152  2008
# 492     2      The Lord of the Rings: The Return of the King       201  2003
#
# ...

# %% [markdown]
# 4. Display all movie names in descending order.

# %%
qry = "SELECT * FROM directors ORDER BY 'Movie Name' DESC;"
df_qry = pd.read_sql_query(qry, conn)
df_qry
# Out:
#       S.no                                         Movie Name  Duration  Year  \
# 0        1                                    The Dark Knight       152  2008
# 1        2      The Lord of the Rings: The Return of the King       201  2003
# 2        3                Spider-Man: Across the Spider-Verse       140  2023
# 3        4                                          Inception       148  2010
# 4        5  The Lord of the Rings: The Fellowship of the Ring       178  2001
# ...    ...                                                ...       ...   ...
# 1770  1771                                              Radhe       109  2021
# 1771  1772                                             Race 3       160  2018
# 1772  1773                                  Angels Apocalypse        85  2015
# 1773  1774                                           Elk*rtuk       125  2021
# 1774  1775                                            Sadak 2       133  2020
#
# ...

# %% [markdown]
# 5. Display movie name starts with ‘P’ and their rating is greater than 7.

# %%
qry = "SELECT * FROM directors WHERE `Movie Name` LIKE 'P%' AND Ratings > 7;"
df_qry = pd.read_sql_query(qry, conn)
df_qry
# Out:
#     S.no                                         Movie Name  Duration  \
# 0     56                                   Paan Singh Tomar       135
# 1     58  Pirates of the Caribbean: The Curse of the Bla...       143
# 2    119                            Per un pugno di dollari        99
# 3    136                                           Predator       107
# 4    240                          Pushpa: The Rise - Part 1       179
# 5    244                                 Ponniyin Selvan: I       167
# 6    303         Pirates of the Caribbean: Dead Man's Chest       151
# 7    306                                     Predestination        97
# 8    362                                       Patriots Day       133
# 9    386                                        Point Break       122
# 10   443                                               Prey       100
# 11   448           Pirates of the Caribbean: At World's End       169
# ...

# %% [markdown]
# 1. Display all movie names with star Arnold Schwarzenegger in ascending order

# %%
qry = "SELECT * FROM stars WHERE star1 IN ('Arnold Schwarzenegger') \
         OR star2 IN ('Arnold Schwarzenegger') \
         OR star3 IN ('Arnold Schwarzenegger') \
         OR star4 IN ('Arnold Schwarzenegger') \
         OR star5 IN ('Arnold Schwarzenegger') \
         OR star6 IN ('Arnold Schwarzenegger') \
         OR star7 IN ('Arnold Schwarzenegger') \
         OR star8 IN ('Arnold Schwarzenegger') \
         OR star9 IN ('Arnold Schwarzenegger') ORDER BY 'Ratings' ASC;"
df_qry = pd.read_sql_query(qry, conn)
df_qry
# Out:
#                             Movie Name    Votes Gross collection  Popularity  \
# 0           Terminator 2: Judgment Day  1135391      204,843,350         8.6
# 1                       The Terminator   895182       38,400,000         8.1
# 2                             Predator   438800       59,735,548         7.8
# 3                         Total Recall   343671      119,394,840         7.5
# 4                            True Lies   272218      146,282,411         7.3
# 5                  Conan the Barbarian   157313       39,565,475         6.9
# 6                          Escape Plan   251804       25,132,228         6.7
# 7                      The Running Man   160372       38,122,105         6.7
# 8                             Commando   169380       35,100,000         6.7
# 9                     Last Action Hero   159102       50,016,394         6.5
# 10                  Terminator Genisys   286677       89,760,956         6.3
# ...

# %% [markdown]
# 2. Display all details of the movie with the highest number of votes

# %%
qry = "SELECT * FROM stars ORDER BY Votes DESC LIMIT 1;"
df_qry = pd.read_sql_query(qry, conn)
df_qry
# Out:
#         Movie Name    Votes Gross collection  Popularity Certification  \
# 0  The Dark Knight  2759160      534,858,444         9.0            UA
#
#             Star1         Star2          Star3          Star4 Star5 Star6  \
# 0  Christian Bale  Heath Ledger  Aaron Eckhart  Michael Caine  None  None
#
#   Star7 Star8 Star9  Genre1 Genre2 Genre3
# 0  None  None  None  Action  Crime  Drama

# %% [markdown]
# 3. Display movie names with gross collections in descending order

# %%
qry = "SELECT * FROM stars ORDER BY `Gross collection` DESC;"
df_qry = pd.read_sql_query(qry, conn)
df_qry
# Out:
#                            Movie Name   Votes Gross collection  Popularity  \
# 0                  Olympus Has Fallen  285631       98,925,640         6.5
# 1                    The Green Hornet  162994       98,780,042         5.8
# 2                        Sherlock Jr.   53496          977,375         8.2
# 3                             Kantara   97292            97292         8.3
# 4                    Inspector Gadget   49844       97,403,112         4.2
# ...                               ...     ...              ...         ...
# 1770                Love and Monsters  136172        1,070,714         6.9
# 1771                      The General   94966        1,033,895         8.1
# 1772                 Attack the Block  109725        1,024,175         6.7
# 1773  Cowboy Bebop: Tengoku no tobira   51117        1,000,045         7.8
# 1774                 Army of the Dead  180188        1,000,000         5.8
#
#      Certification                   Star1             Star2  \
# ...

# %% [markdown]
# 4. Display the gross collection of movies with the star Arnold

# %%
qry = "SELECT `Gross collection` FROM stars WHERE star1 LIKE '%Arnold%' OR star2 LIKE '%Arnold%' OR star3 LIKE '%Arnold%'"
df_qry = pd.read_sql_query(qry, conn)
df_qry
# Out:
#    Gross collection
# 0       204,843,350
# 1        38,400,000
# 2        59,735,548
# 3       119,394,840
# 4       146,282,411
# 5        39,565,475
# 6        25,132,228
# 7        38,122,105
# 8        35,100,000
# 9        50,016,394
# 10       89,760,956
# 11      150,371,112
# 12       12,050,299
# 13       62,253,077
# 14       91,457,688
# 15      101,295,562
# 16       34,994,648
# 17       31,042,035
# 18       34,604,280
# 19       66,889,043
# 20       10,508,518
# 21       16,209,459
# 22       40,077,257
# 23        6,948,633
# 24      107,325,195

# %% [markdown]
# 5.Display all details of movies with comedy and action genres.

# %%
qry = "SELECT * FROM stars WHERE Genre1 = 'Comedy' OR Genre2 = 'Comedy' OR Genre3 = 'Comedy' AND (Genre1 = 'Action' OR Genre2 = 'Action' OR Genre3 = 'Action')"
df_qry = pd.read_sql_query(qry, conn)
df_qry
# Out:
#                                       Movie Name   Votes Gross collection  \
# 0                             Gangs of Wasseypur  100146           100146
# 1                                   Sherlock Jr.   53496          977,375
# 2            Lock, Stock and Two Smoking Barrels  599779        3,897,569
# 3                                    The General   94966        1,033,895
# 4                                     Hera Pheri   70066            70066
# ..                                           ...     ...              ...
# 369                 The Adventures of Pluto Nash   26569        4,420,080
# 370  The Adventures of Sharkboy and Lavagirl 3-D   40477       39,177,684
# 371        Spy Kids 4: All the Time in the World   27294       38,538,188
# 372                                  Heropanti 2   27084            27084
# 373                                       Laxmii   58178            58178
#
#      Popularity Certification                Star1                Star2  \
# ...

# %% [markdown]
# Subqueries
# 1. Display all details from both tables where movie names are the same

# %%
qry = """
SELECT *
FROM directors
INNER JOIN stars ON directors.`Movie Name` = stars.`Movie Name`
"""
df_qry = pd.read_sql_query(qry, conn)
df_qry
# Out:
#       S.no                                         Movie Name  Duration  Year  \
# 0        1                                    The Dark Knight       152  2008
# 1        2      The Lord of the Rings: The Return of the King       201  2003
# 2        3                Spider-Man: Across the Spider-Verse       140  2023
# 3        4                                          Inception       148  2010
# 4        5  The Lord of the Rings: The Fellowship of the Ring       178  2001
# ...    ...                                                ...       ...   ...
# 1832  1771                                              Radhe       109  2021
# 1833  1772                                             Race 3       160  2018
# 1834  1773                                  Angels Apocalypse        85  2015
# 1835  1774                                           Elk*rtuk       125  2021
# 1836  1775                                            Sadak 2       133  2020
#
# ...

# %% [markdown]
# 2. Display all movie names, Director, ratings, and gross collection where the genre is action.

# %%
qry = """
SELECT directors.`Movie Name`, directors.Director1, directors.Director2, directors.Director3,
       directors.Director4, directors.Director5, directors.Director6, directors.Director7,
       directors.Director8, directors.Director9, directors.Ratings, stars.`Gross collection`
FROM directors
INNER JOIN stars ON directors.`Movie Name` = stars.`Movie Name`
WHERE stars.Genre1 = 'Action' OR stars.Genre2 = 'Action' OR stars.Genre3 = 'Action'
"""
df_qry = pd.read_sql_query(qry, conn)
df_qry
# Out:
#                                              Movie Name           Director1  \
# 0                                       The Dark Knight   Christopher Nolan
# 1         The Lord of the Rings: The Return of the King       Peter Jackson
# 2                   Spider-Man: Across the Spider-Verse  Joaquim Dos Santos
# 3                                             Inception   Christopher Nolan
# 4     The Lord of the Rings: The Fellowship of the Ring       Peter Jackson
# ...                                                 ...                 ...
# 1832                                              Radhe         Prabhu Deva
# 1833                                             Race 3        Remo D'Souza
# 1834                                  Angels Apocalypse           Sean Cain
# 1835                                           Elk*rtuk       Keith English
# 1836                                            Sadak 2        Mahesh Bhatt
#
# ...

# %% [markdown]
# 3. Display all details from both tables with the highest gross collection.

# %%
qry = """
SELECT *
FROM Directors
INNER JOIN Stars ON Directors.`Movie Name` = Stars.`Movie Name`
WHERE Stars.`Gross collection` = (
    SELECT MAX(`Gross collection`)
    FROM Stars
)
"""
df_qry = pd.read_sql_query(qry, conn)
df_qry
# Out:
#    S.no          Movie Name  Duration  Year  Ratings  Metascore  \
# 0   891  Olympus Has Fallen       119  2013      6.5       41.0
#
#        Director1      Director2      Director3       Director4  ...  \
# 0  Antoine Fuqua  Gerard Butler  Aaron Eckhart  Morgan Freeman  ...
#
#             Star3           Star4 Star5 Star6 Star7 Star8 Star9  Genre1  \
# 0  Morgan Freeman  Angela Bassett  None  None  None  None  None  Action
#
#      Genre2  Genre3
# 0  Thriller    None
#
# [1 rows x 33 columns]

# %% [markdown]
# 4. Display all details from both tables with the highest ratings

# %%
qry = """
SELECT *
FROM Directors
INNER JOIN Stars ON Directors.`Movie Name` = Stars.`Movie Name`
WHERE Directors.Ratings = (
    SELECT MAX(Ratings)
    FROM Directors
)
"""

df_qry = pd.read_sql_query(qry, conn)
df_qry
# Out:
#    S.no                                     Movie Name  Duration  Year  \
# 0     1                                The Dark Knight       152  2008
# 1     2  The Lord of the Rings: The Return of the King       201  2003
#
#    Ratings  Metascore          Director1       Director2        Director3  \
# 0      9.0       84.0  Christopher Nolan  Christian Bale     Heath Ledger
# 1      9.0       94.0      Peter Jackson     Elijah Wood  Viggo Mortensen
#
#        Director4  ...          Star3          Star4 Star5 Star6 Star7 Star8  \
# 0  Aaron Eckhart  ...  Aaron Eckhart  Michael Caine  None  None  None  None
# 1   Ian McKellen  ...   Ian McKellen  Orlando Bloom  None  None  None  None
#
#   Star9  Genre1     Genre2  Genre3
# 0  None  Action      Crime   Drama
# 1  None  Action  Adventure   Drama
#
# [2 rows x 33 columns]

# %% [markdown]
# 5. Display all details from both tables with the lowest gross collection and lowest ratings

# %%
qry = """
SELECT *
FROM Directors
INNER JOIN Stars ON Directors.`Movie Name` = Stars.`Movie Name`
WHERE Stars.`Gross collection` = (
    SELECT MIN(`Gross collection`)
    FROM Stars
)
AND Directors.Ratings = (
    SELECT MIN(Ratings)
    FROM Directors
)
"""

df_qry = pd.read_sql_query(qry, conn)
df_qry
# Out:
# Empty DataFrame
# Columns: [S.no, Movie Name, Duration, Year, Ratings, Metascore, Director1, Director2, Director3, Director4, Director5, Director6, Director7, Director8, Director9, Director10, Movie Name, Votes, Gross collection, Popularity, Certification, Star1, Star2, Star3, Star4, Star5, Star6, Star7, Star8, Star9, Genre1, Genre2, Genre3]
# Index: []
#
# [0 rows x 33 columns]

# %%
qry = """
SELECT *
FROM Directors
INNER JOIN Stars ON Directors.`Movie Name` = Stars.`Movie Name`
WHERE Stars.`Gross collection` = (
    SELECT MIN(`Gross collection`)
    FROM Stars
)
OR Directors.Ratings = (
    SELECT MIN(Ratings)
    FROM Directors
)
"""

df_qry = pd.read_sql_query(qry, conn)
df_qry
# Out:
#    S.no        Movie Name  Duration  Year  Ratings  Metascore     Director1  \
# 0  1384  Army of the Dead       148  2021      5.8       57.0   Zack Snyder
# 1  1775           Sadak 2       133  2020      1.2        NaN  Mahesh Bhatt
#
#        Director2     Director3          Director4  ...              Star3  \
# 0  Dave Bautista  Ella Purnell  Ana de la Reguera  ...  Ana de la Reguera
# 1     Alia Bhatt   Sanjay Dutt        Pooja Bhatt  ...        Pooja Bhatt
#
#             Star4 Star5 Star6 Star7 Star8 Star9  Genre1 Genre2  Genre3
# 0  Omari Hardwick  None  None  None  None  None  Action  Crime   Drama
# 1   Priyanka Bose  None  None  None  None  None  Action  Drama    None
#
# [2 rows x 33 columns]

# %% [markdown]
# Queries using PANDAS SQL

# %%
df1 = pd.read_csv("imdb_data1.csv")

# %%
df1.head()
# Out:
#    S.no                                         Movie Name  Duration  Year  \
# 0     1                                    The Dark Knight       152  2008
# 1     2      The Lord of the Rings: The Return of the King       201  2003
# 2     3                Spider-Man: Across the Spider-Verse       140  2023
# 3     4                                          Inception       148  2010
# 4     5  The Lord of the Rings: The Fellowship of the Ring       178  2001
#
#    Ratings  Metascore           Director1          Director2  \
# 0      9.0       84.0   Christopher Nolan     Christian Bale
# 1      9.0       94.0       Peter Jackson        Elijah Wood
# 2      8.8       86.0  Joaquim Dos Santos        Kemp Powers
# 3      8.8       74.0   Christopher Nolan  Leonardo DiCaprio
# 4      8.8       92.0       Peter Jackson        Elijah Wood
#
#               Director3      Director4         Director5          Director6  \
# ...

# %%
df2 = pd.read_csv("imdb_data2.csv")

# %%
df2.head()
# Out:
#                                           Movie Name    Votes  \
# 0                                    The Dark Knight  2759160
# 1      The Lord of the Rings: The Return of the King  1906339
# 2                Spider-Man: Across the Spider-Verse   208178
# 3                                          Inception  2449482
# 4  The Lord of the Rings: The Fellowship of the Ring  1934546
#
#   Gross collection  Popularity Certification              Star1  \
# 0      534,858,444         9.0            UA     Christian Bale
# 1      377,845,905         9.0             U        Elijah Wood
# 2           208178         8.8             U        Kemp Powers
# 3      292,576,195         8.8            UA  Leonardo DiCaprio
# 4      315,544,750         8.8             U        Elijah Wood
#
#                   Star2          Star3             Star4              Star5  \
# 0          Heath Ledger  Aaron Eckhart     Michael Caine                NaN
# ...

# %%
df_merge = pd.merge(df1, df2, on='Movie Name', how='inner')

# %%
df_merge.head()
# Out:
#    S.no                                         Movie Name  Duration  Year  \
# 0     1                                    The Dark Knight       152  2008
# 1     2      The Lord of the Rings: The Return of the King       201  2003
# 2     3                Spider-Man: Across the Spider-Verse       140  2023
# 3     4                                          Inception       148  2010
# 4     5  The Lord of the Rings: The Fellowship of the Ring       178  2001
#
#    Ratings  Metascore           Director1          Director2  \
# 0      9.0       84.0   Christopher Nolan     Christian Bale
# 1      9.0       94.0       Peter Jackson        Elijah Wood
# 2      8.8       86.0  Joaquim Dos Santos        Kemp Powers
# 3      8.8       74.0   Christopher Nolan  Leonardo DiCaprio
# 4      8.8       92.0       Peter Jackson        Elijah Wood
#
#               Director3      Director4  ...          Star3             Star4  \
# ...

# %% [markdown]
# 1. Display all the details of movies created by directors Christopher and Matt Reeves.

# %%
df_directors = df1[
    (df1['Director1'] == 'Christopher Nolan') |
    (df1['Director2'] == 'Christopher Nolan') |
    (df1['Director3'] == 'Christopher Nolan') |
    (df1['Director4'] == 'Christopher Nolan') |
    (df1['Director5'] == 'Christopher Nolan') |
    (df1['Director6'] == 'Christopher Nolan') |
    (df1['Director7'] == 'Christopher Nolan') |
    (df1['Director8'] == 'Christopher Nolan') |
    (df1['Director9'] == 'Christopher Nolan') |
    (df1['Director1'] == 'Matt Reeves') |
    (df1['Director2'] == 'Matt Reeves') |
    (df1['Director3'] == 'Matt Reeves') |
    (df1['Director4'] == 'Matt Reeves') |
    (df1['Director5'] == 'Matt Reeves') |
    (df1['Director6'] == 'Matt Reeves') |
    (df1['Director7'] == 'Matt Reeves') |
    (df1['Director8'] == 'Matt Reeves') |
    (df1['Director9'] == 'M')]

df_directors
# Out:
#      S.no                      Movie Name  Duration  Year  Ratings  Metascore  \
# 0       1                 The Dark Knight       152  2008      9.0       84.0
# 3       4                       Inception       148  2010      8.8       74.0
# 16     17           The Dark Knight Rises       164  2012      8.4       78.0
# 36     37                   Batman Begins       140  2005      8.2       70.0
# 129   130                         Dunkirk       106  2017      7.8       94.0
# 131   132                      The Batman       176  2022      7.8       72.0
# 225   226  Dawn of the Planet of the Apes       130  2014      7.6       79.0
# 311   312  War for the Planet of the Apes       140  2017      7.4       82.0
# 324   325                           Tenet       150  2020      7.3       69.0
# 520   521                     Cloverfield        85  2008      7.0       64.0
#
#              Director1              Director2             Director3  \
# ...

# %% [markdown]
# 2. Display all the details of movies with a duration of 140 minutes to 190 minutes

# %%
df_directors = df1[
    (df1['Duration'] >= 140) & (df1['Duration'] <= 190)
]

df_directors
# Out:
#       S.no                                         Movie Name  Duration  Year  \
# 0        1                                    The Dark Knight       152  2008
# 2        3                Spider-Man: Across the Spider-Verse       140  2023
# 3        4                                          Inception       148  2010
# 4        5  The Lord of the Rings: The Fellowship of the Ring       178  2001
# 5        6              The Lord of the Rings: The Two Towers       179  2002
# ...    ...                                                ...       ...   ...
# 1761  1762                                              Liger       140  2022
# 1762  1763                                             Gunday       152  2014
# 1765  1766                                        Heropanti 2       145  2022
# 1766  1767                                             Laxmii       141  2020
# 1771  1772                                             Race 3       160  2018
#
# ...

# %% [markdown]
# 3. Display all details of movies with ratings above 7 in ascending order

# %%
df_directors = df1[df1['Ratings'] > 7]

df_sort = df_directors.sort_values('Ratings', ascending=True)

df_sort
# Out:
#      S.no                                         Movie Name  Duration  Year  \
# 492   493                                     Gabbar Is Back       128  2015
# 459   460                                          Desperado       104  1995
# 458   459                                           Creed II       130  2018
# 457   458                                  Deepwater Horizon       107  2016
# 456   457                             The Poseidon Adventure       117  1972
# ..    ...                                                ...       ...   ...
# 4       5  The Lord of the Rings: The Fellowship of the Ring       178  2001
# 3       4                                          Inception       148  2010
# 2       3                Spider-Man: Across the Spider-Verse       140  2023
# 1       2      The Lord of the Rings: The Return of the King       201  2003
# 0       1                                    The Dark Knight       152  2008
#
# ...

# %% [markdown]
# 4. Display all movie names in descending order

# %%
df_sort = df1.sort_values('Movie Name', ascending=False)
df_sort = df_sort.reset_index(drop=True)
title = df_sort['Movie Name']
title
# Out:
# 0                     Ölümlü Dünya
# 1                         Æon Flux
# 2          xXx: State of the Union
# 3       xXx: Return of Xander Cage
# 4                              xXx
#                    ...
# 1770                     12 Rounds
# 1771                     10,000 BC
# 1772               1 - Nenokkadine
# 1773                           '71
# 1774                     #Saraitda
# Name: Movie Name, Length: 1775, dtype: object

# %% [markdown]
# 5. Display movie name starts with ‘P’ and their rating is greater than 7

# %%
df_directors = df1[(df1['Movie Name'].str.startswith('P')) & (df1['Ratings'] > 7)]
title = df_directors['Movie Name']

title
# Out:
# 55                                      Paan Singh Tomar
# 57     Pirates of the Caribbean: The Curse of the Bla...
# 118                              Per un pugno di dollari
# 135                                             Predator
# 239                            Pushpa: The Rise - Part 1
# 243                                   Ponniyin Selvan: I
# 302           Pirates of the Caribbean: Dead Man's Chest
# 305                                       Predestination
# 361                                         Patriots Day
# 385                                          Point Break
# 442                                                 Prey
# 447             Pirates of the Caribbean: At World's End
# 471                                              Payback
# Name: Movie Name, dtype: object

# %% [markdown]
# Stars Table
# 1. Display all movie names with star Arnold Schwarzenegger in ascending order

# %%
stars = ['Star1', 'Star2', 'Star3', 'Star4', 'Star5', 'Star6', 'Star7', 'Star8', 'Star9']

df_melt = pd.melt(df2, id_vars=['Movie Name'], value_vars=stars, var_name='Star Number', value_name='Star Name')

df_filt = df_melt.dropna(subset=['Star Name'])

df_filt = df_filt[df_filt['Star Name'].str.contains('Arnold Schwarzenegger', case=False)]

title = df_filt['Movie Name'].sort_values(ascending=True)

for i in title:
    print(i)
# Out:
# Batman & Robin
# Collateral Damage
# Commando
# Conan the Barbarian
# Conan the Destroyer
# End of Days
# Eraser
# Escape Plan
# Kindergarten Cop
# Last Action Hero
# Predator
# Raw Deal
# Red Heat
# Red Sonja
# Sabotage
# Terminator 2: Judgment Day
# Terminator 3: Rise of the Machines
# Terminator Genisys
# Terminator: Dark Fate
# The 6th Day
# The Last Stand
# The Running Man
# The Terminator
# Total Recall
# True Lies

# %% [markdown]
# 2. Display all details of the movie with the highest number of votes

# %%
title = df2.loc[df2['Votes'].idxmax()]
title
# Out:
# Movie Name          The Dark Knight
# Votes                       2759160
# Gross collection        534,858,444
# Popularity                      9.0
# Certification                    UA
# Star1                Christian Bale
# Star2                  Heath Ledger
# Star3                 Aaron Eckhart
# Star4                 Michael Caine
# Star5                           NaN
# Star6                           NaN
# Star7                           NaN
# Star8                           NaN
# Star9                           NaN
# Genre1                       Action
# Genre2                        Crime
# Genre3                        Drama
# Name: 0, dtype: object

# %% [markdown]
# 3. Display movie names with gross collections in descending order

# %%
df_sort = df2.sort_values('Gross collection', ascending=False)
title = df_sort['Movie Name']
title
# Out:
# 890                  Olympus Has Fallen
# 1413                   The Green Hornet
# 50                         Sherlock Jr.
# 31                              Kantara
# 1732                   Inspector Gadget
#                      ...
# 600                   Love and Monsters
# 70                          The General
# 720                    Attack the Block
# 162     Cowboy Bebop: Tengoku no tobira
# 1383                   Army of the Dead
# Name: Movie Name, Length: 1775, dtype: object

# %% [markdown]
# 4. Display the gross collection of movies with the star Arnold

# %%
df_filt = df2.loc[
    (df2['Star1'].str.contains('Arnold', na=False)) |
    (df2['Star2'].str.contains('Arnold', na=False)) |
    (df2['Star3'].str.contains('Arnold', na=False)) |
    (df2['Star4'].str.contains('Arnold', na=False)) |
    (df2['Star5'].str.contains('Arnold', na=False)) |
    (df2['Star6'].str.contains('Arnold', na=False)) |
    (df2['Star7'].str.contains('Arnold', na=False)) |
    (df2['Star8'].str.contains('Arnold', na=False)) |
    (df2['Star9'].str.contains('Arnold', na=False))]

title = df_filt['Gross collection']
title
# Out:
# 9       204,843,350
# 58       38,400,000
# 135      59,735,548
# 258     119,394,840
# 332     146,282,411
# 435     155,247,825
# 574      39,565,475
# 690      25,132,228
# 698      38,122,105
# 703      35,100,000
# 891      50,016,394
# 926     202,019,785
# 1007     89,760,956
# 1018    150,371,112
# 1047     12,050,299
# 1087     62,253,077
# 1102     91,457,688
# 1128    101,295,562
# 1228     34,994,648
# 1335     31,042,035
# 1341     34,604,280
# 1399     66,889,043
# 1468     10,508,518
# 1505     16,209,459
# 1561     40,077,257
# 1657      6,948,633
# 1745    107,325,195
# Name: Gross collection, dtype: object

# %% [markdown]
# 5. Display all details of movies with comedy and action genres

# %%
df_filt = df2[
    (df2['Genre1'] == 'Comedy') | (df2['Genre2'] == 'Comedy') | (df2['Genre3'] == 'Comedy')
    & (df2['Genre1'] == 'Action') | (df2['Genre2'] == 'Action') | (df2['Genre3'] == 'Action')
]

df_filt
# Out:
#                                        Movie Name   Votes Gross collection  \
# 2             Spider-Man: Across the Spider-Verse  208178           208178
# 18              Spider-Man: Into the Spider-Verse  617896      190,241,310
# 29                                  Mononoke-hime  412524        2,375,308
# 45             Kimetsu no Yaiba: Mugen Ressha-Hen   66782       47,700,000
# 46                             Gangs of Wasseypur  100146           100146
# ...                                           ...     ...              ...
# 1744                 The Adventures of Pluto Nash   26569        4,420,080
# 1748  The Adventures of Sharkboy and Lavagirl 3-D   40477       39,177,684
# 1754        Spy Kids 4: All the Time in the World   27294       38,538,188
# 1765                                  Heropanti 2   27084            27084
# 1766                                       Laxmii   58178            58178
#
# ...

# %% [markdown]
# Subqueries
# 1. Display all details from both tables where movie names are the same

# %%
df_merge
# Out:
#       S.no                                         Movie Name  Duration  Year  \
# 0        1                                    The Dark Knight       152  2008
# 1        2      The Lord of the Rings: The Return of the King       201  2003
# 2        3                Spider-Man: Across the Spider-Verse       140  2023
# 3        4                                          Inception       148  2010
# 4        5  The Lord of the Rings: The Fellowship of the Ring       178  2001
# ...    ...                                                ...       ...   ...
# 1832  1771                                              Radhe       109  2021
# 1833  1772                                             Race 3       160  2018
# 1834  1773                                  Angels Apocalypse        85  2015
# 1835  1774                                           Elk*rtuk       125  2021
# 1836  1775                                            Sadak 2       133  2020
#
# ...

# %% [markdown]
# 2. Display all movie names, Director, ratings, and gross collection where the genre is action

# %%
title = df2[
    (df2['Genre1'].str.lower() == 'action') |
    (df2['Genre2'].str.lower() == 'action') |
    (df2['Genre3'].str.lower() == 'action')
]

df_merge = pd.merge(df1, title, on='Movie Name', how='inner')

cols = ['Movie Name', 'Director1', 'Director2', 'Director3', 'Director4', 'Director5',
                   'Director6', 'Director7', 'Director8', 'Director9', 'Director10', 'Ratings', 'Gross collection']
dfcols = df_merge[cols]

dfcols
# Out:
#                                              Movie Name           Director1  \
# 0                                       The Dark Knight   Christopher Nolan
# 1         The Lord of the Rings: The Return of the King       Peter Jackson
# 2                   Spider-Man: Across the Spider-Verse  Joaquim Dos Santos
# 3                                             Inception   Christopher Nolan
# 4     The Lord of the Rings: The Fellowship of the Ring       Peter Jackson
# ...                                                 ...                 ...
# 1832                                              Radhe         Prabhu Deva
# 1833                                             Race 3        Remo D'Souza
# 1834                                  Angels Apocalypse           Sean Cain
# 1835                                           Elk*rtuk       Keith English
# 1836                                            Sadak 2        Mahesh Bhatt
#
# ...

# %% [markdown]
# 3. Display all details from both tables with the highest gross collection

# %%
df_cols = df_merge['Gross collection'].max()

df_res = df_merge[df_merge['Gross collection'] == df_cols]

df_res
# Out:
#      S.no          Movie Name  Duration  Year  Ratings  Metascore  \
# 948   891  Olympus Has Fallen       119  2013      6.5       41.0
#
#          Director1      Director2      Director3       Director4  ...  \
# 948  Antoine Fuqua  Gerard Butler  Aaron Eckhart  Morgan Freeman  ...
#
#               Star3           Star4 Star5 Star6 Star7 Star8  Star9  Genre1  \
# 948  Morgan Freeman  Angela Bassett   NaN   NaN   NaN   NaN    NaN  Action
#
#        Genre2 Genre3
# 948  Thriller    NaN
#
# [1 rows x 32 columns]

# %% [markdown]
# 4. Display all details from both tables with the highest ratings

# %%
df_cols = df_merge['Ratings'].max()
df_res = df_merge[df_merge['Ratings'] == df_cols]

df_res
# Out:
#    S.no                                     Movie Name  Duration  Year  \
# 0     1                                The Dark Knight       152  2008
# 1     2  The Lord of the Rings: The Return of the King       201  2003
#
#    Ratings  Metascore          Director1       Director2        Director3  \
# 0      9.0       84.0  Christopher Nolan  Christian Bale     Heath Ledger
# 1      9.0       94.0      Peter Jackson     Elijah Wood  Viggo Mortensen
#
#        Director4  ...          Star3          Star4 Star5 Star6 Star7 Star8  \
# 0  Aaron Eckhart  ...  Aaron Eckhart  Michael Caine   NaN   NaN   NaN   NaN
# 1   Ian McKellen  ...   Ian McKellen  Orlando Bloom   NaN   NaN   NaN   NaN
#
#    Star9  Genre1     Genre2 Genre3
# 0    NaN  Action      Crime  Drama
# 1    NaN  Action  Adventure  Drama
#
# [2 rows x 32 columns]

# %% [markdown]
# 5. Display all details from both tables with the lowest gross collection and lowest ratings

# %%
df_merge = pd.merge(df1, df2, on='Movie Name', how='inner')

lowest_gross = df_merge[df_merge['Gross collection'] == df_merge['Gross collection'].min()]
lowest_ratings = df_merge[df_merge['Ratings'] == df_merge['Ratings'].min()]

print("Movies with the lowest gross collection:")
print(lowest_gross)

print("Movies with the lowest ratings:")
print(lowest_ratings)
# Out:
# Movies with the lowest gross collection:
#       S.no        Movie Name  Duration  Year  Ratings  Metascore    Director1  \
# 1453  1384  Army of the Dead       148  2021      5.8       57.0  Zack Snyder
#
#           Director2     Director3          Director4  ...              Star3  \
# 1453  Dave Bautista  Ella Purnell  Ana de la Reguera  ...  Ana de la Reguera
#
#                Star4 Star5 Star6 Star7 Star8  Star9  Genre1  Genre2 Genre3
# 1453  Omari Hardwick   NaN   NaN   NaN   NaN    NaN  Action   Crime  Drama
#
# [1 rows x 32 columns]
# Movies with the lowest ratings:
#       S.no Movie Name  Duration  Year  Ratings  Metascore     Director1  \
# 1836  1775    Sadak 2       133  2020      1.2        NaN  Mahesh Bhatt
#
#        Director2    Director3    Director4  ...        Star3          Star4  \
# 1836  Alia Bhatt  Sanjay Dutt  Pooja Bhatt  ...  Pooja Bhatt  Priyanka Bose
#
#      Star5 Star6 Star7 Star8  Star9  Genre1  Genre2 Genre3
# ...
